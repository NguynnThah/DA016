# %% [markdown]
# # 05_student_data_preprocessing - Tiền xử lý dữ liệu khảo sát sinh viên
#
# Mục tiêu:
# - Làm sạch dữ liệu khảo sát sinh viên.
# - Xử lý câu trả lời không hợp lệ.
# - Chuẩn hóa thang đo Digital Burnout Scale.
# - Kết hợp dữ liệu Screen Time và hành vi học tập.
# - Tạo dataset nghiên cứu chính thức.
#
# Notebook này **không thực hiện**:
# - Huấn luyện mô hình
# - SHAP/Interpretability
