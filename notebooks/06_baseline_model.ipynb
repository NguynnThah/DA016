# %% [markdown]
# # 06_baseline_model - Xây dựng mô hình cơ sở
#
# Mục tiêu:
# - Huấn luyện các mô hình baseline.
# - Thiết lập mốc so sánh ban đầu.
# - Đánh giá hiệu năng bằng Accuracy, Precision, Recall và F1-score.
#
# Notebook này **không thực hiện**:
# - Tuning nâng cao
# - SHAP/Interpretability
