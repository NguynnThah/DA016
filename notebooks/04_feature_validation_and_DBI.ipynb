# %% [markdown]
# # 04_feature_validation_and_DBI - Kiểm chứng chỉ báo và xây dựng DBI
#
# Mục tiêu:
# - Kiểm chứng vai trò của 20 thuộc tính nghiên cứu.
# - Kiểm tra đa cộng tuyến và mức độ liên quan của biến.
# - Xây dựng nguyên mẫu Digital Burnout Index (DBI).
# - Đề xuất khung chỉ báo Digital Burnout.
#
# Notebook này **không thực hiện**:
# - Huấn luyện mô hình chính thức
# - Đánh giá trên dữ liệu sinh viên
