# %% [markdown]
# # 07_main_model - Xây dựng mô hình chính
#
# Mục tiêu:
# - Huấn luyện các mô hình chính như Random Forest, XGBoost hoặc LightGBM.
# - Tối ưu hiệu năng dự đoán Digital Burnout.
# - Lưu kết quả và mô hình tốt nhất.
#
# Notebook này **không thực hiện**:
# - So sánh tổng hợp cuối cùng
# - SHAP/Interpretability
