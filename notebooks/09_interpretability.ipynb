# %% [markdown]
# # 09_interpretability - Giải thích mô hình
#
# Mục tiêu:
# - Sử dụng SHAP hoặc Feature Importance để giải thích mô hình.
# - Xác định các yếu tố ảnh hưởng mạnh nhất đến Digital Burnout.
# - Hỗ trợ diễn giải kết quả theo góc nhìn nghiên cứu.
#
# Notebook này **không thực hiện**:
# - Huấn luyện lại toàn bộ mô hình
# - Thay đổi pipeline xử lý dữ liệu
